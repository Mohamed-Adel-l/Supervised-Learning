# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-Adel-l/Supervised-Learning/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
from google.colab import files
# Download latest version
"""path = kagglehub.dataset_download("abhishek14398/salary-dataset-simple-linear-regression")

print("Path to dataset files:", path)

data=pd.read_csv(path+"/Salary_Data.csv")
print(data.head())"""
# Out:
# 'path = kagglehub.dataset_download("abhishek14398/salary-dataset-simple-linear-regression")\n\nprint("Path to dataset files:", path)\n\ndata=pd.read_csv(path+"/Salary_Data.csv")\nprint(data.head())'

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ca489431-0c75-4af9-adf2-dd4495538b25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca489431-0c75-4af9-adf2-dd4495538b25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("archive.zip")
print(data.head())
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x=np.array(data['YearsExperience']).reshape(-1,1)
y=np.array(data['Salary']).reshape(-1,1)
print(f"feature:\n{x[:5]}\nprediction:\n{y[:5]}")
# Out:
# feature:
# [[1.2]
#  [1.4]
#  [1.6]
#  [2.1]
#  [2.3]]
# prediction:
# [[39344.]
#  [46206.]
#  [37732.]
#  [43526.]
#  [39892.]]

# %%
scaler = StandardScaler()
x=scaler.fit_transform(x)
print(f"feature:\n{x[:5]}")
# Out:
# feature:
# [[-1.51005294]
#  [-1.43837321]
#  [-1.36669348]
#  [-1.18749416]
#  [-1.11581443]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
model=LinearRegression()
model.fit(x_train,y_train)
yhat=model.predict(x_test)
mse=root_mean_squared_error(y_test,yhat)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 7492.50

# %%
plt.scatter(x_test,y_test,color="green")
plt.plot(x_test,yhat,color="orange")
plt.show()
